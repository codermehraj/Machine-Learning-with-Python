# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn as sns

# %% [markdown]
# Input Variables:
#
#
# ---
#
#
# 1. Number of times pregnant
#
# 2. Plasma glucose concentration at 2 hours in an oral glucose tolerance test
#
# 3. Diastolic blood pressure (mm Hg)
#
# 4. Triceps skin fold thickness (mm)
#
# 5. 2-hour serum insulin (mu U/ml)
#
# 6. Body mass index (weight in kg/(height in m)^2)
#
# 7. Diabetes pedigree function
#
# 8. Age (years)
#
#
# Output Variable:
#
#
# ---
#
# Class variable (0 or 1)

# %%
data_path = './nn_data.txt'
dataset = pd.read_csv(data_path, header=None)
dataset.shape
print(dataset.head())
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
# split into input (X) and output (y) variables
# split into input (X) and output (y) variables
X = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]

# %%
X.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %% [markdown]
# ### Data Scaling (Normalizing)

# %%
from sklearn.preprocessing import MinMaxScaler

scaling_columns = [0,1,2,3,4,5,6,7]
scaler = MinMaxScaler()

X[scaling_columns] = scaler.fit_transform(X[scaling_columns])

X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.352941  0.743719  0.590164  0.353535  0.000000  0.500745  0.234415
# 1  0.058824  0.427136  0.540984  0.292929  0.000000  0.396423  0.116567
# 2  0.470588  0.919598  0.524590  0.000000  0.000000  0.347243  0.253629
# 3  0.058824  0.447236  0.540984  0.232323  0.111111  0.418778  0.038002
# 4  0.000000  0.688442  0.327869  0.353535  0.198582  0.642325  0.943638
#
#           7
# 0  0.483333
# 1  0.166667
# 2  0.183333
# 3  0.000000
# 4  0.200000

# %%
# define the keras model
model = Sequential()
model.add(Dense(8, input_shape=(8,), activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 2ms/step - loss: 0.6808 - accuracy: 0.5990
# Epoch 2/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6576 - accuracy: 0.6523
# Epoch 3/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6397 - accuracy: 0.6510
# Epoch 4/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6306 - accuracy: 0.6510
# Epoch 5/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6239 - accuracy: 0.6510
# Epoch 6/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6167 - accuracy: 0.6510
# Epoch 7/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6098 - accuracy: 0.6510
# Epoch 8/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6015 - accuracy: 0.6680
# Epoch 9/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5930 - accuracy: 0.6836
# Epoch 10/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5834 - accuracy: 0.6810
# Epoch 11/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7083
# Epoch 12/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5646 - accuracy: 0.7083
# Epoch 13/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5548 - accuracy: 0.7161
# Epoch 14/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7292
# Epoch 15/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5379 - accuracy: 0.7344
# Epoch 16/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5284 - accuracy: 0.7461
# Epoch 17/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5252 - accuracy: 0.7474
# Epoch 18/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5167 - accuracy: 0.7474
# Epoch 19/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5125 - accuracy: 0.7526
# Epoch 20/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5067 - accuracy: 0.7552
# Epoch 21/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5006 - accuracy: 0.7630
# Epoch 22/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4967 - accuracy: 0.7656
# Epoch 23/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.7747
# Epoch 24/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4935 - accuracy: 0.7799
# Epoch 25/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4879 - accuracy: 0.7682
# Epoch 26/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.7682
# Epoch 27/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4828 - accuracy: 0.7760
# Epoch 28/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7812
# Epoch 29/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.7760
# Epoch 30/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.7747
# Epoch 31/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7799
# Epoch 32/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.7878
# Epoch 33/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.7852
# Epoch 34/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4683 - accuracy: 0.7799
# Epoch 35/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7812
# Epoch 36/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4643 - accuracy: 0.7734
# Epoch 37/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4652 - accuracy: 0.7878
# Epoch 38/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7773
# Epoch 39/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4591 - accuracy: 0.7839
# Epoch 40/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7760
# Epoch 41/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4577 - accuracy: 0.7773
# Epoch 42/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7852
# Epoch 43/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4567 - accuracy: 0.7812
# Epoch 44/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4556 - accuracy: 0.7812
# Epoch 45/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.7786
# Epoch 46/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4617 - accuracy: 0.7799
# Epoch 47/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4558 - accuracy: 0.7839
# Epoch 48/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.7852
# Epoch 49/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4532 - accuracy: 0.7878
# Epoch 50/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4519 - accuracy: 0.7852
# Epoch 51/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4534 - accuracy: 0.7891
# Epoch 52/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4523 - accuracy: 0.7891
# Epoch 53/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.7747
# Epoch 54/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4507 - accuracy: 0.7852
# Epoch 55/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4483 - accuracy: 0.7904
# Epoch 56/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4481 - accuracy: 0.7839
# Epoch 57/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7878
# Epoch 58/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7891
# Epoch 59/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.7891
# Epoch 60/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.7878
# Epoch 61/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.7826
# Epoch 62/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7904
# Epoch 63/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.7943
# Epoch 64/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7904
# Epoch 65/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.7878
# Epoch 66/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4485 - accuracy: 0.7878
# Epoch 67/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.7839
# Epoch 68/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.7878
# Epoch 69/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4423 - accuracy: 0.7995
# Epoch 70/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4433 - accuracy: 0.7904
# Epoch 71/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4447 - accuracy: 0.7904
# Epoch 72/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.8008
# Epoch 73/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4416 - accuracy: 0.7956
# Epoch 74/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.7930
# Epoch 75/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.7930
# Epoch 76/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.7852
# Epoch 77/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4404 - accuracy: 0.7943
# Epoch 78/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.7917
# Epoch 79/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.7865
# Epoch 80/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.7917
# Epoch 81/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7943
# Epoch 82/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4393 - accuracy: 0.7904
# Epoch 83/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4413 - accuracy: 0.7904
# Epoch 84/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4395 - accuracy: 0.7917
# Epoch 85/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.7969
# Epoch 86/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4387 - accuracy: 0.7969
# Epoch 87/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.7930
# Epoch 88/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4386 - accuracy: 0.7865
# Epoch 89/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.7943
# Epoch 90/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4361 - accuracy: 0.7904
# Epoch 91/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4356 - accuracy: 0.7930
# Epoch 92/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.7956
# Epoch 93/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.7930
# Epoch 94/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4355 - accuracy: 0.7891
# Epoch 95/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4340 - accuracy: 0.7904
# Epoch 96/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.7930
# Epoch 97/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.7904
# Epoch 98/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.7956
# Epoch 99/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.7917
# Epoch 100/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4331 - accuracy: 0.7956

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4304 - accuracy: 0.7982
# Accuracy: 79.82

# %%
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print(' %d (expected %d)' % ( predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 1ms/step
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
